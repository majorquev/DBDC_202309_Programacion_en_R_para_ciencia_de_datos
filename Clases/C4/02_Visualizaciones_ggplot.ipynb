# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202309_Programacion_en_R_para_ciencia_de_datos/blob/main/Clases/C4/02_Visualizaciones_ggplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 3: Introducción a GGplot2
#
# **Autor:** Miguel Jorquera Viguera<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Rodrigo Morales<br>
# **E-mail ayudante:** rumorale1@gmail.com
#
# Ggplot es una librería basada en la gramática de gráficos, creadapor Wilkinson (2015). Básicamente la gramática de gráficos nos dice que un gráfico estadístico corresponde a un mapeo entre la data hacia atributos estéticos (como el color, forma o tamaño) de objetos geométricos (como puntos, líneas o barras).
#
# ## Referencias útiles
#
#  * https://ggplot2.tidyverse.org/reference/index.html
#  * https://r4ds.had.co.nz/data-visualisation.html
#  * https://www.rdocumentation.org/packages/ggplot2/versions/3.3.0
#
#
# ## Cheatsheets
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Cargamos la librería
library(ggplot2) # install.packages("ggplot2")
# Otras librerías que pueden ser de interés: leaflet, iplots, highcharter * ,ggmap, visNetwork**

# %% [markdown]
# Para entender el funcionamiento de esta grámatica comencemos con un ejemplo analizando la data mpg:

# %%
# "+" es mas o menos lo mismo en ggplot que %>% de dplyr
data(mpg)
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 21  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 22  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 23  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 28  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 205 toyota       toyota tacoma 4wd  3.4   1999 6   auto(l4)   4   15  19  r
# 206 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 207 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 208 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 209 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 210 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 211 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 212 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 214 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 215 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 217 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 218 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 219 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 220 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 221 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 222 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 223 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 224 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 225 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 226 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 227 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 228 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 229 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 230 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 231 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 232 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 233 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 234 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact
# 15  compact
# 16  midsize
# 17  midsize
# 18  midsize
# 19  suv
# 20  suv
# 21  suv
# 22  suv
# 23  suv
# 24  2seater
# 25  2seater
# 26  2seater
# 27  2seater
# 28  2seater
# 29  suv
# 30  suv
# ⋮   ⋮
# 205 pickup
# 206 pickup
# 207 pickup
# 208 compact
# 209 compact
# 210 compact
# 211 compact
# 212 compact
# 213 compact
# 214 compact
# 215 compact
# 216 compact
# 217 compact
# 218 compact
# 219 compact
# 220 compact
# 221 compact
# 222 subcompact
# 223 subcompact
# 224 subcompact
# 225 subcompact
# 226 subcompact
# 227 subcompact
# 228 midsize
# 229 midsize
# 230 midsize
# 231 midsize
# 232 midsize
# 233 midsize
# 234 midsize

# %%
# Esto es R base (No ggplot)
plot(mpg$displ, mpg$hwy,col = "blue")
# Out:
# plot without title

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mpg %>%
  ggplot() + # Indicamos el origen de los datos que buscamos visualizar
  aes(x = displ, y = hwy) + # capa "estética" : aesthetical mapping (indicamos qué variables queremos visualizar)
  geom_point() # capa geométrica, se indica "cómo" queremos visualizar las variables indicadas en el aesthetical mapping
# Out:
# plot without title

# %%
# tambien podemos generar el gráfico de la siguiente manera (aes( coo parametro mapping))
ggplot(mpg, mapping = aes(x = displ, y = hwy)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# # I. Color, tamaño, forma y otros atributos estéticos
#
# ## I.1. Color
# El color está dado por la variable categórica class (notar que es lo mismo si incluimos el parámetro color, colour o col. ggplot automáticamente entiende lo que queremos :) )

# %%
## Color por "class" dentro de aes
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = class) +
  geom_point()
# Out:
# plot without title

# %%
#y si queremos color azul?
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = "lalala") +
  geom_point()

mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point(color = "#68ab94")
# Out:
# plot without title
# plot without title

# %%
# Que pasa si queremos colorear de un tono solo los de class "2seater", y el resto de otro color.
mpg %>%
  mutate(class2 = ifelse(class != "2seater", "otro", class )) %>%
  ggplot() +
  aes(x = displ, y = hwy, color = class2) +
  geom_point() +
  scale_colour_manual(values = c("black", "red"))

# Desafío: Cómo podríamos customizar el color de "2seater" y "otro"
# Out:
# plot without title

# %%
# class "factor"
data(iris)

# %%
iris2 <- iris
iris2$Species <- as.character(iris2$Species)

# %%
iris2
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# 15  5.8          4.0         1.2          0.2         setosa
# 16  5.7          4.4         1.5          0.4         setosa
# 17  5.4          3.9         1.3          0.4         setosa
# 18  5.1          3.5         1.4          0.3         setosa
# 19  5.7          3.8         1.7          0.3         setosa
# 20  5.1          3.8         1.5          0.3         setosa
# 21  5.4          3.4         1.7          0.2         setosa
# 22  5.1          3.7         1.5          0.4         setosa
# 23  4.6          3.6         1.0          0.2         setosa
# 24  5.1          3.3         1.7          0.5         setosa
# 25  4.8          3.4         1.9          0.2         setosa
# 26  5.0          3.0         1.6          0.2         setosa
# 27  5.0          3.4         1.6          0.4         setosa
# 28  5.2          3.5         1.5          0.2         setosa
# 29  5.2          3.4         1.4          0.2         setosa
# 30  4.7          3.2         1.6          0.2         setosa
# ⋮   ⋮            ⋮           ⋮            ⋮           ⋮
# 121 6.9          3.2         5.7          2.3         virginica
# 122 5.6          2.8         4.9          2.0         virginica
# 123 7.7          2.8         6.7          2.0         virginica
# 124 6.3          2.7         4.9          1.8         virginica
# 125 6.7          3.3         5.7          2.1         virginica
# 126 7.2          3.2         6.0          1.8         virginica
# 127 6.2          2.8         4.8          1.8         virginica
# 128 6.1          3.0         4.9          1.8         virginica
# 129 6.4          2.8         5.6          2.1         virginica
# 130 7.2          3.0         5.8          1.6         virginica
# 131 7.4          2.8         6.1          1.9         virginica
# 132 7.9          3.8         6.4          2.0         virginica
# 133 6.4          2.8         5.6          2.2         virginica
# 134 6.3          2.8         5.1          1.5         virginica
# 135 6.1          2.6         5.6          1.4         virginica
# 136 7.7          3.0         6.1          2.3         virginica
# 137 6.3          3.4         5.6          2.4         virginica
# 138 6.4          3.1         5.5          1.8         virginica
# 139 6.0          3.0         4.8          1.8         virginica
# 140 6.9          3.1         5.4          2.1         virginica
# 141 6.7          3.1         5.6          2.4         virginica
# 142 6.9          3.1         5.1          2.3         virginica
# 143 5.8          2.7         5.1          1.9         virginica
# 144 6.8          3.2         5.9          2.3         virginica
# 145 6.7          3.3         5.7          2.5         virginica
# 146 6.7          3.0         5.2          2.3         virginica
# 147 6.3          2.5         5.0          1.9         virginica
# 148 6.5          3.0         5.2          2.0         virginica
# 149 6.2          3.4         5.4          2.3         virginica
# 150 5.9          3.0         5.1          1.8         virginica

# %%
summary(iris2)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#    Species
#  Length:150
#  Class :character
#  Mode  :character

# %%
class(iris$Species)
class(iris2$Species)
# Out:
# [1] "factor"
# [1] "character"

# %%
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
unique(iris2$Species)
# Out:
# [1] "setosa"     "versicolor" "virginica"

# %%
# que sucede si el color no es una variable discreta (categórica)

mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = cyl) +
  geom_point()
# Out:
# plot without title

# %%
# Modificar el parámetro alpha y dar la impresión de "intensidad"
  ggplot() +
  aes(x = rnorm(10000) , y =  rnorm(10000)) +
  geom_point(alpha = 0.2)

  ggplot() +
  aes(x = rnorm(10000) , y =  rnorm(10000)) +
  geom_point()
# Out:
# plot without title
# plot without title

# %%
# Modificar la escala de colores del "degradé"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = cyl) +
  geom_point() +
  scale_color_gradient(low = "#cf133e", high = "#5e66f7" )
# Out:
# plot without title

# %%
unique(mpg$cyl)
# Out:
# [1] 4 6 8 5

# %% [markdown]
# ## I.2. Forma

# %%
## Forma (shape) según "drv"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, shape = drv) +
  geom_point()
# Out:
# plot without title

# %%
# El parámetro alpha permite regular la intensidad el color en función de la densidad de los puntos.

# %% [markdown]
# ## I.3. Forma y color

# %%
## Forma y color (color = class, shape = drv)

# %% [markdown]
# ## I.4. Tamaño

# %%
## Tamaño (size) según "cyl"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, size = cyl) +
  geom_point()
# Out:
# plot without title

# %%
# size = drv? nota: no tiene sentido dar el tamaño segú nuna variable categórica (R internamente la ordena alfabéticamente y luego asigna el valor del tamañao)
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, size = drv) +
  geom_point()
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# # II. Facetas
#
# En inglés Facetting, es una manera de dividir la data disponible según variables categóricas y mostrar el mismo gráfico por cada categoría en una misma imagen.

# %%
# Apertura por drv (small multiples en PBI)
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  facet_wrap(~drv)
# Out:
# plot without title

# %% [markdown]
# Grafique otras relaciones entre la eficiencia (hwy o cty), tamaño del motor (displ) por cada  número de cilindros (cyl). ¿Qué se observa?

# %%
# Por ejemplo, x=displ,y=hwy , aperturado por número de cilindros

# %% [markdown]
# # III. Capas geométricas: prefijo geom_
#
# Hasta aquí hemos utilizado sólo una de las diversas maneras de mostrar (geométricamente hablando) la relación entre las variables hasta aquí descritas.
# En ggplot existe una gran variedad de funciones "geom_", sólo veremos algunas de ellas, aunque en la documentación oficial se describen todas las opciones disponibles https://ggplot2.tidyverse.org/index.html
#
# ## III.1 geom_point()
#
# La fución geom_point() se encarga de visualizar las variables definidas en aes() como un gráfico de dispersión.
#
# ## III.2 geom_smooth()
# Con esta función podemos añadir una curva de tendencia a nuestros datos

# %%
#geom_smooth()
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
?geom_smooth

# %%
#geom_smooth()
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# ¿Cómo podemos graficar las curvas de tendencia para cada tipo de tracción (drv)?

# %%
# por color
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = drv) +
  geom_point() +
  geom_smooth()


mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth() +
  facet_wrap(~drv)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ## III.3 geom_boxplot() y geom_jitter()
#  Podemos variar la forma del gráfico modificando la capa geométrica con las funciones geom_
#  Por ejemplo, hace un rato visualizamos la relación entre hwy y drv. Para este tipo de relaciones es más informativo un gráfico de cajas.

# %%
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_point()
# Out:
# plot without title

# %%
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_point(color = "red") +
  geom_jitter()
# Out:
# plot without title

# %%
# Boxplots o gràficos de caja
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ## III.4 geom_histogram() y  geom_freqpoly()
#
# Con estas funciones es posible graficar histogramas y la frecuencia absoluta a través de una curva poligonal

# %%
## histograma . Parámetro bins =30 en geom_histogram()

# %%
# Con base
hist(mpg$hwy, breaks = 30)
# Out:
# Plot with title “Histogram of mpg$hwy”

# %%
ggplot(mpg) +
  aes(x = hwy) +
  geom_histogram(
    color = "black",
    fill = "grey"
  )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# podemos aperturar por drv (en color  y fill)
ggplot(mpg) +
  aes(x = hwy, color = drv, fill = drv) +
  geom_histogram( )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(mpg) +
  aes(x = hwy) +
  geom_histogram( ) +
  facet_wrap(~drv)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
## polígono de frecuencias # geom_freqpoly

ggplot(mpg) +
  aes(x = hwy, color = drv) +
  geom_freqpoly( )


ggplot(mpg) +
  aes(x = hwy, color = drv) +
  geom_freqpoly( ) +
  facet_wrap(~drv)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# ## III.4 geom_line()
#
# Podemos generar gráficos de linea, por ejemplo de series temporales.

# %%
library(dplyr)
library(httr)
library(jsonlite)
library(ggplot2)

url_base <-"https://mindicador.cl"

consulta <- GET(url_base,path = "/api/dolar/2023")
consulta
# Out:
# Response [https://mindicador.cl/api/dolar/2023]
#   Date: 2023-10-23 22:02
#   Status: 200
#   Content-Type: application/json; charset=utf-8
#   Size: 10.7 kB

# %%
text <- content(consulta, as = "text")
text
# Out:
# [1] "{\"version\":\"1.7.0\",\"autor\":\"mindicador.cl\",\"codigo\":\"dolar\",\"nombre\":\"Dólar observado\",\"unidad_medida\":\"Pesos\",\"serie\":[{\"fecha\":\"2023-10-24T03:00:00.000Z\",\"valor\":938.26},{\"fecha\":\"2023-10-23T03:00:00.000Z\",\"valor\":942.42},{\"fecha\":\"2023-10-20T03:00:00.000Z\",\"valor\":940.46},{\"fecha\":\"2023-10-19T03:00:00.000Z\",\"valor\":937.21},{\"fecha\":\"2023-10-18T03:00:00.000Z\",\"valor\":945.61},{\"fecha\":\"2023-10-17T03:00:00.000Z\",\"valor\":942.8},{\"fecha\":\"2023-10-16T03:00:00.000Z\",\"valor\":942.04},{\"fecha\":\"2023-10-13T03:00:00.000Z\",\"valor\":933.45},{\"fecha\":\"2023-10-12T03:00:00.000Z\",\"valor\":924.81},{\"fecha\":\"2023-10-11T03:00:00.000Z\",\"valor\":927.07},{\"fecha\":\"2023-10-10T03:00:00.000Z\",\"valor\":919.42},{\"fecha\":\"2023-10-06T03:00:00.000Z\",\"valor\":917.34},{\"fecha\":\"2023-10-05T03:00:00.000Z\",\"valor\":913.26},{\"fecha\":\"2
z\",\"valor\":848.5},{\"fecha\":\"2023-08-04T04:00:00.000Z\",\"valor\":853.99},{\"fecha\":\"2023-08-03T04:00:00.000Z\",\"valor\":847.77},{\"fecha\":\"2023-08-02T04:00:00.000Z\",\"valor\":843.02},{\"fecha\":\"2023-08-01T04:00:00.000Z\",\"valor\":840.69},{\"fecha\":\"2023-07-31T04:00:00.000Z\",\"valor\":827.84},{\"fecha\":\"2023-07-28T04:00:00.000Z\",\"valor\":826.01},{\"fecha\":\"2023-07-27T04:00:00.000Z\",\"valor\":825.8},{\"fecha\":\"2023-07-26T04:00:00.000Z\",\"valor\":828.9},{\"fecha\":\"2023-07-25T04:00:00.000Z\",\"valor\":827.1},{\"fecha\":\"2023-07-24T04:00:00.000Z\",\"valor\":821.95},{\"fecha\":\"2023-07-21T04:00:00.000Z\",\"valor\":807.62},{\"fecha\":\"2023-07-20T04:00:00.000Z\",\"valor\":811.43},{\"fecha\":\"2023-07-19T04:00:00.000Z\",\"valor\":815.58},{\"fecha\":\"2023-07-18T04:00:00.00 ...

# %%
content <- fromJSON(text)
content
# Out:
# $version
# [1] "1.7.0"
#
# $autor
# [1] "mindicador.cl"
#
# $codigo
# [1] "dolar"
#
# $nombre
# [1] "Dólar observado"
#
# $unidad_medida
# [1] "Pesos"
#
# $serie
#                        fecha  valor
# 1   2023-10-24T03:00:00.000Z 938.26
# 2   2023-10-23T03:00:00.000Z 942.42
# 3   2023-10-20T03:00:00.000Z 940.46
# 4   2023-10-19T03:00:00.000Z 937.21
# 5   2023-10-18T03:00:00.000Z 945.61
# 6   2023-10-17T03:00:00.000Z 942.80
# 7   2023-10-16T03:00:00.000Z 942.04
# 8   2023-10-13T03:00:00.000Z 933.45
# 9   2023-10-12T03:00:00.000Z 924.81
# 10  2023-10-11T03:00:00.000Z 927.07
# 11  2023-10-10T03:00:00.000Z 919.42
# 12  2023-10-06T03:00:00.000Z 917.34
# 13  2023-10-05T03:00:00.000Z 913.26
# 14  2023-10-04T03:00:00.000Z 914.30
# 15  2023-10-03T03:00:00.000Z 902.26
# 16  2023-10-02T03:00:00.000Z 895.60
# 17  2023-09-29T03:00:00.000Z 906.84
# 18  2023-09-28T03:00:00.000Z 904.62
# 19  2023-09-27T03:00:00.000Z 904.31
# 20  2023-09-26T03:00:00.000Z 900.14
# 21  2023-09-25T03:00:00.000Z 889.21
# 22  2023-09-22T03:00:00.000Z 891.73
# 23  2023-09-21T03:00:00.000Z 882.31
# 24  2023-09-20T03:00:00.000Z 887.89
# 25  2023-09-15T03:00:00.000Z 885.84
# 26  2023-09-14T03:00:00.000Z 888.34
# 27  2023-09-13T03:00:00.000Z 897.17
# 28  2023-09-12T03:00:00.000Z 890.81
# 29  2023-09-11T03:00:00.000Z 892.68
# 30  2023-09-08T03:00:00.000Z 879.77
# 31  2023-09-07T03:00:00.000Z 872.92
# 32  2023-09-06T03:00:00.000Z 869.67
# 33  2023-09-05T03:00:00.000Z 854.99
# 201 2023-01-05T03:00:00.000Z 855.10
# 202 2023-01-04T03:00:00.000Z 852.14
# 203 2023-01-03T03:00:00.000Z 855.86

# %% [markdown]
# # IV. Otros parámetros visuales
#
# Primero graficaremos la serie de valores del dolar.

# %%
names(content$serie)
# Out:
# [1] "fecha" "valor"

# %%
head(content$serie)
# Out:
#   fecha                    valor
# 1 2023-10-24T03:00:00.000Z 938.26
# 2 2023-10-23T03:00:00.000Z 942.42
# 3 2023-10-20T03:00:00.000Z 940.46
# 4 2023-10-19T03:00:00.000Z 937.21
# 5 2023-10-18T03:00:00.000Z 945.61
# 6 2023-10-17T03:00:00.000Z 942.80

# %%
content$serie %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot()+
  aes(x = fecha, y = valor) +
  geom_line()
# Out:
# plot without title

# %% [markdown]
# ## IV.1 Etiquetas
# Con la capa llamada `labs()`, podemos modificar los nombres de los ejes, títulos, subtítulos y leyenda.

# %%
## Ejemplo, consideramos incluir etiquetas y cortes en el eje de tiempo
content$serie %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot()+
  aes(x = fecha, y = valor) +
  geom_line() +
  labs(x = "Fecha de observación del dolar",
       y = "Dólar observado",
       title = "Serie dolar observado",
       subtitle = "Año 2023",
       caption = "Fuente: https://mindicador.cl/")
# Out:
# plot without title

# %% [markdown]
# ## IV.2 Ejes y escala
# Existen diversas funciones que nos peritirán modificar parámetros visuales de los ejes, en función del tipo de dato que estos representen. Algunos de los más usuales son los siguientes
#  * `scale_x_date()`, `scale_y_date()`
#  * `scale_x_continuous()`, `scale_y_continuous()`
#  * `scale_x_discrete()`, `scale_y_discrete()`
#  * `scale_x_log10()`, `scale_y_log10()`
#
# En la documentación pueden buscar las demmás opcione mediante el prefijo _scale_

# %%
?scale_x_date

# %%
content$serie %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot()+
  aes(x = fecha, y = valor) +
  geom_line() +
  labs(x = "Fecha de observación del dolar",
       y = "Dólar observado",
       title = "Serie dolar observado",
       subtitle = "Año 2023",
       caption = "Fuente: https://mindicador.cl/") +
  scale_x_date(date_breaks = "1 month", date_labels = "%b %Y")
# Out:
# plot without title

# %%
cortes1 <- seq(from = as.Date("2023-01-01"), to = as.Date("2023-07-01"), length.out = 3)

# %%
cortes2 <- seq(from = as.Date("2023-08-01"), to = as.Date("2023-11-01"), length.out = 4)

# %%
cortes <- c(cortes1,cortes2)
cortes
# Out:
# [1] "2023-01-01" "2023-04-01" "2023-07-01" "2023-08-01" "2023-08-31"
# [6] "2023-10-01" "2023-11-01"

# %%
content$serie %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot()+
  aes(x = fecha, y = valor) +
  geom_line() +
  labs(x = "Fecha de observación del dolar",
       y = "Dólar observado",
       title = "Serie dolar observado",
       subtitle = "Año 2023",
       caption = "Fuente: https://mindicador.cl/") +
  scale_x_date(breaks = cortes, date_labels = "%d-%b %Y")
# Out:
# plot without title
